# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#!pip install opencv-python

# %%
img =cv2.imread('./test/vk18.jpg')
img.shape
# Out:
# (266, 400, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (266, 400)

# %%
gray
# Out:
# array([[207, 207, 206, ..., 200, 200, 200],
#        [207, 206, 206, ..., 201, 200, 199],
#        [206, 206, 206, ..., 201, 199, 199],
#        ...,
#        [221, 221, 222, ..., 219, 219, 219],
#        [221, 221, 221, ..., 219, 218, 218],
#        [221, 221, 221, ..., 219, 218, 218]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3,5)
faces
# Out:
# array([[151,  54, 146, 146]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (151, 54, 146, 146)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap = 'gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test/vk18.jpg')
plt.imshow(original_image)

# %%
cropped_img = get_cropped_image_if_2_eyes('./test/vk18.jpg')
plt.imshow(cropped_img)

# %%
obs_image = cv2.imread('./test/vk2.jpg')
plt.imshow(obs_image)

# %%
cropped_img2 = get_cropped_image_if_2_eyes('./test/vk2.jpg')
cropped_img2

# %%
path_to_data = './dataset'
path_to_cr_data = './dataset/cropped'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
img_dirs
# Out:
# ['./dataset\\lionel_messi',
#  './dataset\\mbappe',
#  './dataset\\ms_dhoni',
#  './dataset\\neymar',
#  './dataset\\rohit_sharma',
#  './dataset\\Ronaldo',
#  './dataset\\virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_img_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('\\')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data +'/'+ celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_img_dirs.append(cropped_folder)
                print("Generating cropped images in folder : ", cropped_folder)
                
            cropped_file_name = celebrity_name +str(count) +".png"
            cropped_file_path = cropped_folder + '/' + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# lionel_messi
# Generating cropped images in folder :  ./dataset/cropped/lionel_messi
# mbappe
# Generating cropped images in folder :  ./dataset/cropped/mbappe
# ms_dhoni
# Generating cropped images in folder :  ./dataset/cropped/ms_dhoni
# neymar
# Generating cropped images in folder :  ./dataset/cropped/neymar
# rohit_sharma
# Generating cropped images in folder :  ./dataset/cropped/rohit_sharma
# Ronaldo
# Generating cropped images in folder :  ./dataset/cropped/Ronaldo
# virat_kohli
# Generating cropped images in folder :  ./dataset/cropped/virat_kohli

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./dataset/cropped/lionel_messi/lionel_messi1.png',
#   './dataset/cropped/lionel_messi/lionel_messi2.png',
#   './dataset/cropped/lionel_messi/lionel_messi3.png',
#   './dataset/cropped/lionel_messi/lionel_messi4.png',
#   './dataset/cropped/lionel_messi/lionel_messi5.png',
#   './dataset/cropped/lionel_messi/lionel_messi6.png',
#   './dataset/cropped/lionel_messi/lionel_messi7.png',
#   './dataset/cropped/lionel_messi/lionel_messi8.png',
#   './dataset/cropped/lionel_messi/lionel_messi9.png',
#   './dataset/cropped/lionel_messi/lionel_messi10.png',
#   './dataset/cropped/lionel_messi/lionel_messi11.png',
#   './dataset/cropped/lionel_messi/lionel_messi12.png',
#   './dataset/cropped/lionel_messi/lionel_messi13.png',
#   './dataset/cropped/lionel_messi/lionel_messi14.png',
#   './dataset/cropped/lionel_messi/lionel_messi15.png',
#   './dataset/cropped/lionel_messi/lionel_messi16.png',
#   './dataset/cropped/lionel_messi/lionel_messi17.png',
#   './dataset/cropped/lionel_messi/lionel_messi18.png',
#   './dataset/cropped/lionel_messi/lionel_messi19.png',
#   './dataset/cropped/lionel_messi/lionel_messi20.png',
#   './dataset/cropped/lionel_messi/lionel_messi21.png',
#   './dataset/cropped/lionel_messi/lionel_messi22.png',
#   './dataset/cropped/lionel_messi/lionel_messi23.png',
#   './dataset/cropped/lionel_messi/lionel_messi24.png',
#   './dataset/cropped/lionel_messi/lionel_messi25.png',
#   './dataset/cropped/lionel_messi/lionel_messi26.png',
#   './dataset/cropped/lionel_messi/lionel_messi27.png',
#   './dataset/cropped/lionel_messi/lionel_messi28.png',
#   './dataset/cropped/lionel_messi/lionel_messi29.png',
#   './dataset/cropped/lionel_messi/lionel_messi30.png',
#   './dataset/cropped/lionel_messi/lionel_messi31.png',
#   './dataset/cropped/lionel_messi/lionel_messi32.png',
#   './dataset/cropped/lionel_messi/lionel_messi33.png',
#   './dataset/cropped/lionel_messi/lionel_messi34.png',
#   './dataset/cropped/lionel_messi/lionel_messi35.png',
#   './dataset/cropped/lionel_messi/lionel_messi36.png',
#   './dataset/cropped/lionel_messi/lionel_messi37.png',
#   './dataset/cropped/lionel_messi/lionel_messi38.png',
#   './dataset/cropped/lionel_messi/lionel_messi39.png',
#   './dataset/cropped/lionel_messi/lionel_messi40.png',
#   './dataset/cropped/lionel_messi/lionel_messi41.png',
#   './dataset/cropped/lionel_messi/lionel_messi42.png',
#   './dataset/cropped/lionel_messi/lionel_messi43.png',
#   './dataset/cropped/lionel_messi/lionel_messi44.png',
#   './dataset/cropped/lionel_messi/lionel_messi45.png',
#   './dataset/cropped/lionel_messi/lionel_messi46.png',
#   './dataset/cropped/lionel_messi/lionel_messi47.png',
#   './dataset/cropped/lionel_messi/lionel_messi48.png',
#   './dataset/cropped/lionel_messi/lionel_messi49.png',
#   './dataset/cropped/lionel_messi/lionel_messi50.png',
#   './dataset/cropped/lionel_messi/lionel_messi51.png',
#   './dataset/cropped/lionel_messi/lionel_messi52.png',
#   './dataset/cropped/lionel_messi/lionel_messi53.png',
#   './dataset/cropped/lionel_messi/lionel_messi54.png',
#   './dataset/cropped/lionel_messi/lionel_messi55.png',
#   './dataset/cropped/lionel_messi/lionel_messi56.png',
#   './dataset/cropped/lionel_messi/lionel_messi57.png',
#   './dataset/cropped/lionel_messi/lionel_messi58.png',
#   './dataset/cropped/lionel_messi/lionel_messi59.png',
#   './dataset/cropped/lionel_messi/lionel_messi60.png',
#   './dataset/cropped/lionel_messi/lionel_messi61.png',
#   './dataset/cropped/lionel_messi/lionel_messi62.png',
#   './dataset/cropped/lionel_messi/lionel_messi63.png',
#   './dataset/cropped/lionel_messi/lionel_messi64.png',
#   './dataset/cropped/lionel_messi/lionel_messi65.png',
#   './dataset/cropped/lionel_messi/lionel_messi66.png',
#   './dataset/cropped/lionel_messi/lionel_messi67.png',
#   './dataset/cropped/lionel_messi/lionel_messi68.png',
#   './dataset/cropped/lionel_messi/lionel_messi69.png',
#   './dataset/cropped/lionel_messi/lionel_messi70.png',
#   './dataset/cropped/lionel_messi/lionel_messi71.png',
#   './dataset/cropped/lionel_messi/lionel_messi72.png',
#   './dataset/cropped/lionel_messi/lionel_messi73.png',
#   './dataset/cropped/lionel_messi/lionel_messi74.png',
#   './dataset/cropped/lionel_messi/lionel_messi75.png',
#   './dataset/cropped/lionel_messi/lionel_messi76.png',
#   './dataset/cropped/lionel_messi/lionel_messi77.png',
#   './dataset/cropped/lionel_messi/lionel_messi78.png',
#   './dataset/cropped/lionel_messi/lionel_messi79.png',
#   './dataset/cropped/lionel_messi/lionel_messi80.png',
#   './dataset/cropped/lionel_messi/lionel_messi81.png',
#   './dataset/cropped/lionel_messi/lionel_messi82.png',
#   './dataset/cropped/lionel_messi/lionel_messi83.png',
#   './dataset/cropped/lionel_messi/lionel_messi84.png',
#   './dataset/cropped/lionel_messi/lionel_messi85.png',
#   './dataset/cropped/lionel_messi/lionel_messi86.png',
#   './dataset/cropped/lionel_messi/lionel_messi87.png',
#   './dataset/cropped/lionel_messi/lionel_messi88.png',
#   './dataset/cropped/lionel_messi/lionel_messi89.png',
#   './dataset/cropped/lionel_messi/lionel_messi90.png',
#   './dataset/cropped/lionel_messi/lionel_messi91.png',
#   './dataset/cropped/lionel_messi/lionel_messi92.png'],
#  'mbappe': ['./dataset/cropped/mbappe/mbappe1.png',
#   './dataset/cropped/mbappe/mbappe2.png',
#   './dataset/cropped/mbappe/mbappe3.png',
#   './dataset/cropped/mbappe/mbappe4.png',
#   './dataset/cropped/mbappe/mbappe5.png',
#   './dataset/cropped/mbappe/mbappe6.png',
#   './dataset/cropped/mbappe/mbappe7.png',
#   './dataset/cropped/mbappe/mbappe8.png',
#   './dataset/cropped/mbappe/mbappe9.png',
#   './dataset/cropped/mbappe/mbappe10.png',
#   './dataset/cropped/mbappe/mbappe11.png',
#   './dataset/cropped/mbappe/mbappe12.png',
#   './dataset/cropped/mbappe/mbappe13.png',
#   './dataset/cropped/mbappe/mbappe14.png',
#   './dataset/cropped/mbappe/mbappe15.png',
#   './dataset/cropped/mbappe/mbappe16.png',
#   './dataset/cropped/mbappe/mbappe17.png',
#   './dataset/cropped/mbappe/mbappe18.png',
#   './dataset/cropped/mbappe/mbappe19.png',
#   './dataset/cropped/mbappe/mbappe20.png',
#   './dataset/cropped/mbappe/mbappe21.png',
#   './dataset/cropped/mbappe/mbappe22.png',
#   './dataset/cropped/mbappe/mbappe23.png',
#   './dataset/cropped/mbappe/mbappe24.png',
#   './dataset/cropped/mbappe/mbappe25.png',
#   './dataset/cropped/mbappe/mbappe26.png',
#   './dataset/cropped/mbappe/mbappe27.png',
#   './dataset/cropped/mbappe/mbappe28.png',
#   './dataset/cropped/mbappe/mbappe29.png',
#   './dataset/cropped/mbappe/mbappe30.png',
#   './dataset/cropped/mbappe/mbappe31.png',
#   './dataset/cropped/mbappe/mbappe32.png',
#   './dataset/cropped/mbappe/mbappe33.png',
#   './dataset/cropped/mbappe/mbappe34.png',
#   './dataset/cropped/mbappe/mbappe35.png',
#   './dataset/cropped/mbappe/mbappe36.png',
#   './dataset/cropped/mbappe/mbappe37.png',
#   './dataset/cropped/mbappe/mbappe38.png',
#   './dataset/cropped/mbappe/mbappe39.png',
#   './dataset/cropped/mbappe/mbappe40.png',
#   './dataset/cropped/mbappe/mbappe41.png',
#   './dataset/cropped/mbappe/mbappe42.png',
#   './dataset/cropped/mbappe/mbappe43.png',
#   './dataset/cropped/mbappe/mbappe44.png',
#   './dataset/cropped/mbappe/mbappe45.png',
#   './dataset/cropped/mbappe/mbappe46.png',
#   './dataset/cropped/mbappe/mbappe47.png',
#   './dataset/cropped/mbappe/mbappe48.png',
#   './dataset/cropped/mbappe/mbappe49.png',
#   './dataset/cropped/mbappe/mbappe50.png',
#   './dataset/cropped/mbappe/mbappe51.png',
#   './dataset/cropped/mbappe/mbappe52.png',
#   './dataset/cropped/mbappe/mbappe53.png',
#   './dataset/cropped/mbappe/mbappe54.png',
#   './dataset/cropped/mbappe/mbappe55.png',
#   './dataset/cropped/mbappe/mbappe56.png',
#   './dataset/cropped/mbappe/mbappe57.png',
#   './dataset/cropped/mbappe/mbappe58.png',
#   './dataset/cropped/mbappe/mbappe59.png',
#   './dataset/cropped/mbappe/mbappe60.png',
#   './dataset/cropped/mbappe/mbappe61.png',
#   './dataset/cropped/mbappe/mbappe62.png',
#   './dataset/cropped/mbappe/mbappe63.png',
#   './dataset/cropped/mbappe/mbappe64.png'],
#  'ms_dhoni': ['./dataset/cropped/ms_dhoni/ms_dhoni1.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni2.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni3.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni4.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni5.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni6.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni7.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni8.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni9.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni10.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni11.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni12.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni13.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni14.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni15.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni16.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni17.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni18.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni19.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni20.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni21.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni22.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni23.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni24.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni25.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni26.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni27.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni28.png',
#   './dataset/cropped/ms_dhoni/ms_dhoni29.png'],
#  'neymar': ['./dataset/cropped/neymar/neymar1.png',
#   './dataset/cropped/neymar/neymar2.png',
#   './dataset/cropped/neymar/neymar3.png',
#   './dataset/cropped/neymar/neymar4.png',
#   './dataset/cropped/neymar/neymar5.png',
#   './dataset/cropped/neymar/neymar6.png',
#   './dataset/cropped/neymar/neymar7.png',
#   './dataset/cropped/neymar/neymar8.png',
#   './dataset/cropped/neymar/neymar9.png',
#   './dataset/cropped/neymar/neymar10.png',
#   './dataset/cropped/neymar/neymar11.png',
#   './dataset/cropped/neymar/neymar12.png',
#   './dataset/cropped/neymar/neymar13.png',
#   './dataset/cropped/neymar/neymar14.png',
#   './dataset/cropped/neymar/neymar15.png',
#   './dataset/cropped/neymar/neymar16.png',
#   './dataset/cropped/neymar/neymar17.png',
#   './dataset/cropped/neymar/neymar18.png',
#   './dataset/cropped/neymar/neymar19.png',
#   './dataset/cropped/neymar/neymar20.png',
#   './dataset/cropped/neymar/neymar21.png'],
#  'rohit_sharma': ['./dataset/cropped/rohit_sharma/rohit_sharma1.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma2.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma3.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma4.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma5.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma6.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma7.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma8.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma9.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma10.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma11.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma12.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma13.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma14.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma15.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma16.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma17.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma18.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma19.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma20.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma21.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma22.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma23.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma24.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma25.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma26.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma27.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma28.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma29.png',
#   './dataset/cropped/rohit_sharma/rohit_sharma30.png'],
#  'Ronaldo': ['./dataset/cropped/Ronaldo/Ronaldo1.png',
#   './dataset/cropped/Ronaldo/Ronaldo2.png',
#   './dataset/cropped/Ronaldo/Ronaldo3.png',
#   './dataset/cropped/Ronaldo/Ronaldo4.png',
#   './dataset/cropped/Ronaldo/Ronaldo5.png',
#   './dataset/cropped/Ronaldo/Ronaldo6.png',
#   './dataset/cropped/Ronaldo/Ronaldo7.png',
#   './dataset/cropped/Ronaldo/Ronaldo8.png',
#   './dataset/cropped/Ronaldo/Ronaldo9.png',
#   './dataset/cropped/Ronaldo/Ronaldo10.png',
#   './dataset/cropped/Ronaldo/Ronaldo11.png',
#   './dataset/cropped/Ronaldo/Ronaldo12.png',
#   './dataset/cropped/Ronaldo/Ronaldo13.png',
#   './dataset/cropped/Ronaldo/Ronaldo14.png',
#   './dataset/cropped/Ronaldo/Ronaldo15.png',
#   './dataset/cropped/Ronaldo/Ronaldo16.png',
#   './dataset/cropped/Ronaldo/Ronaldo17.png',
#   './dataset/cropped/Ronaldo/Ronaldo18.png',
#   './dataset/cropped/Ronaldo/Ronaldo19.png',
#   './dataset/cropped/Ronaldo/Ronaldo20.png',
#   './dataset/cropped/Ronaldo/Ronaldo21.png',
#   './dataset/cropped/Ronaldo/Ronaldo22.png',
#   './dataset/cropped/Ronaldo/Ronaldo23.png',
#   './dataset/cropped/Ronaldo/Ronaldo24.png',
#   './dataset/cropped/Ronaldo/Ronaldo25.png',
#   './dataset/cropped/Ronaldo/Ronaldo26.png',
#   './dataset/cropped/Ronaldo/Ronaldo27.png',
#   './dataset/cropped/Ronaldo/Ronaldo28.png',
#   './dataset/cropped/Ronaldo/Ronaldo29.png',
#   './dataset/cropped/Ronaldo/Ronaldo30.png',
#   './dataset/cropped/Ronaldo/Ronaldo31.png',
#   './dataset/cropped/Ronaldo/Ronaldo32.png',
#   './dataset/cropped/Ronaldo/Ronaldo33.png',
#   './dataset/cropped/Ronaldo/Ronaldo34.png',
#   './dataset/cropped/Ronaldo/Ronaldo35.png',
#   './dataset/cropped/Ronaldo/Ronaldo36.png',
#   './dataset/cropped/Ronaldo/Ronaldo37.png',
#   './dataset/cropped/Ronaldo/Ronaldo38.png',
#   './dataset/cropped/Ronaldo/Ronaldo39.png',
#   './dataset/cropped/Ronaldo/Ronaldo40.png',
#   './dataset/cropped/Ronaldo/Ronaldo41.png',
#   './dataset/cropped/Ronaldo/Ronaldo42.png',
#   './dataset/cropped/Ronaldo/Ronaldo43.png',
#   './dataset/cropped/Ronaldo/Ronaldo44.png',
#   './dataset/cropped/Ronaldo/Ronaldo45.png',
#   './dataset/cropped/Ronaldo/Ronaldo46.png',
#   './dataset/cropped/Ronaldo/Ronaldo47.png',
#   './dataset/cropped/Ronaldo/Ronaldo48.png',
#   './dataset/cropped/Ronaldo/Ronaldo49.png',
#   './dataset/cropped/Ronaldo/Ronaldo50.png',
#   './dataset/cropped/Ronaldo/Ronaldo51.png',
#   './dataset/cropped/Ronaldo/Ronaldo52.png',
#   './dataset/cropped/Ronaldo/Ronaldo53.png',
#   './dataset/cropped/Ronaldo/Ronaldo54.png',
#   './dataset/cropped/Ronaldo/Ronaldo55.png',
#   './dataset/cropped/Ronaldo/Ronaldo56.png',
#   './dataset/cropped/Ronaldo/Ronaldo57.png',
#   './dataset/cropped/Ronaldo/Ronaldo58.png',
#   './dataset/cropped/Ronaldo/Ronaldo59.png',
#   './dataset/cropped/Ronaldo/Ronaldo60.png',
#   './dataset/cropped/Ronaldo/Ronaldo61.png',
#   './dataset/cropped/Ronaldo/Ronaldo62.png',
#   './dataset/cropped/Ronaldo/Ronaldo63.png',
#   './dataset/cropped/Ronaldo/Ronaldo64.png',
#   './dataset/cropped/Ronaldo/Ronaldo65.png',
#   './dataset/cropped/Ronaldo/Ronaldo66.png',
#   './dataset/cropped/Ronaldo/Ronaldo67.png',
#   './dataset/cropped/Ronaldo/Ronaldo68.png',
#   './dataset/cropped/Ronaldo/Ronaldo69.png',
#   './dataset/cropped/Ronaldo/Ronaldo70.png',
#   './dataset/cropped/Ronaldo/Ronaldo71.png',
#   './dataset/cropped/Ronaldo/Ronaldo72.png',
#   './dataset/cropped/Ronaldo/Ronaldo73.png',
#   './dataset/cropped/Ronaldo/Ronaldo74.png',
#   './dataset/cropped/Ronaldo/Ronaldo75.png',
#   './dataset/cropped/Ronaldo/Ronaldo76.png',
#   './dataset/cropped/Ronaldo/Ronaldo77.png',
#   './dataset/cropped/Ronaldo/Ronaldo78.png'],
#  'virat_kohli': ['./dataset/cropped/virat_kohli/virat_kohli1.png',
#   './dataset/cropped/virat_kohli/virat_kohli2.png',
#   './dataset/cropped/virat_kohli/virat_kohli3.png',
#   './dataset/cropped/virat_kohli/virat_kohli4.png',
#   './dataset/cropped/virat_kohli/virat_kohli5.png',
#   './dataset/cropped/virat_kohli/virat_kohli6.png',
#   './dataset/cropped/virat_kohli/virat_kohli7.png',
#   './dataset/cropped/virat_kohli/virat_kohli8.png',
#   './dataset/cropped/virat_kohli/virat_kohli9.png',
#   './dataset/cropped/virat_kohli/virat_kohli10.png',
#   './dataset/cropped/virat_kohli/virat_kohli11.png',
#   './dataset/cropped/virat_kohli/virat_kohli12.png',
#   './dataset/cropped/virat_kohli/virat_kohli13.png',
#   './dataset/cropped/virat_kohli/virat_kohli14.png',
#   './dataset/cropped/virat_kohli/virat_kohli15.png',
#   './dataset/cropped/virat_kohli/virat_kohli16.png',
#   './dataset/cropped/virat_kohli/virat_kohli17.png',
#   './dataset/cropped/virat_kohli/virat_kohli18.png',
#   './dataset/cropped/virat_kohli/virat_kohli19.png',
#   './dataset/cropped/virat_kohli/virat_kohli20.png',
#   './dataset/cropped/virat_kohli/virat_kohli21.png',
#   './dataset/cropped/virat_kohli/virat_kohli22.png',
#   './dataset/cropped/virat_kohli/virat_kohli23.png',
#   './dataset/cropped/virat_kohli/virat_kohli24.png',
#   './dataset/cropped/virat_kohli/virat_kohli25.png',
#   './dataset/cropped/virat_kohli/virat_kohli26.png',
#   './dataset/cropped/virat_kohli/virat_kohli27.png',
#   './dataset/cropped/virat_kohli/virat_kohli28.png',
#   './dataset/cropped/virat_kohli/virat_kohli29.png',
#   './dataset/cropped/virat_kohli/virat_kohli30.png',
#   './dataset/cropped/virat_kohli/virat_kohli31.png',
#   './dataset/cropped/virat_kohli/virat_kohli32.png',
#   './dataset/cropped/virat_kohli/virat_kohli33.png',
#   './dataset/cropped/virat_kohli/virat_kohli34.png',
#   './dataset/cropped/virat_kohli/virat_kohli35.png',
#   './dataset/cropped/virat_kohli/virat_kohli36.png',
#   './dataset/cropped/virat_kohli/virat_kohli37.png',
#   './dataset/cropped/virat_kohli/virat_kohli38.png',
#   './dataset/cropped/virat_kohli/virat_kohli39.png',
#   './dataset/cropped/virat_kohli/virat_kohli40.png',
#   './dataset/cropped/virat_kohli/virat_kohli41.png',
#   './dataset/cropped/virat_kohli/virat_kohli42.png',
#   './dataset/cropped/virat_kohli/virat_kohli43.png',
#   './dataset/cropped/virat_kohli/virat_kohli44.png',
#   './dataset/cropped/virat_kohli/virat_kohli45.png',
#   './dataset/cropped/virat_kohli/virat_kohli46.png',
#   './dataset/cropped/virat_kohli/virat_kohli47.png',
#   './dataset/cropped/virat_kohli/virat_kohli48.png',
#   './dataset/cropped/virat_kohli/virat_kohli49.png',
#   './dataset/cropped/virat_kohli/virat_kohli50.png',
#   './dataset/cropped/virat_kohli/virat_kohli51.png',
#   './dataset/cropped/virat_kohli/virat_kohli52.png',
#   './dataset/cropped/virat_kohli/virat_kohli53.png',
#   './dataset/cropped/virat_kohli/virat_kohli54.png',
#   './dataset/cropped/virat_kohli/virat_kohli55.png',
#   './dataset/cropped/virat_kohli/virat_kohli56.png',
#   './dataset/cropped/virat_kohli/virat_kohli57.png',
#   './dataset/cropped/virat_kohli/virat_kohli58.png',
#   './dataset/cropped/virat_kohli/virat_kohli59.png',
#   './dataset/cropped/virat_kohli/virat_kohli60.png',
#   './dataset/cropped/virat_kohli/virat_kohli61.png',
#   './dataset/cropped/virat_kohli/virat_kohli62.png',
#   './dataset/cropped/virat_kohli/virat_kohli63.png',
#   './dataset/cropped/virat_kohli/virat_kohli64.png',
#   './dataset/cropped/virat_kohli/virat_kohli65.png',
#   './dataset/cropped/virat_kohli/virat_kohli66.png',
#   './dataset/cropped/virat_kohli/virat_kohli67.png',
#   './dataset/cropped/virat_kohli/virat_kohli68.png',
#   './dataset/cropped/virat_kohli/virat_kohli69.png',
#   './dataset/cropped/virat_kohli/virat_kohli70.png',
#   './dataset/cropped/virat_kohli/virat_kohli71.png',
#   './dataset/cropped/virat_kohli/virat_kohli72.png',
#   './dataset/cropped/virat_kohli/virat_kohli73.png',
#   './dataset/cropped/virat_kohli/virat_kohli74.png',
#   './dataset/cropped/virat_kohli/virat_kohli75.png',
#   './dataset/cropped/virat_kohli/virat_kohli76.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count += 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'mbappe': 1,
#  'ms_dhoni': 2,
#  'neymar': 3,
#  'rohit_sharma': 4,
#  'Ronaldo': 5,
#  'virat_kohli': 6}

# %%
X = []
y = []

for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scaled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        scaled_img_har = cv2.resize(img_har,(32,32))
        combined_img = np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (352, 4096)

# %%
y[0]
# Out:
# 0

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7386363636363636

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.73      0.74        22
#            1       0.58      1.00      0.73        15
#            2       0.00      0.00      0.00         9
#            3       1.00      0.33      0.50         3
#            4       1.00      0.67      0.80         6
#            5       0.76      0.80      0.78        20
#            6       0.87      1.00      0.93        13
#
#     accuracy                           0.74        88
#    macro avg       0.71      0.65      0.64        88
# weighted avg       0.69      0.74      0.70        88
# C:\Users\BRISTI\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\BRISTI\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\BRISTI\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.678302
# 1        random_forest    0.507184
# 2  logistic_regression    0.689478
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7727272727272727

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4659090909090909

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7954545454545454

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[18,  2,  0,  1,  0,  1,  0],
#        [ 0, 11,  1,  0,  1,  1,  1],
#        [ 0,  2,  5,  0,  1,  1,  0],
#        [ 0,  0,  0,  3,  0,  0,  0],
#        [ 0,  1,  0,  0,  5,  0,  0],
#        [ 1,  3,  0,  0,  0, 16,  0],
#        [ 0,  0,  0,  0,  1,  0, 12]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 0,
#  'mbappe': 1,
#  'ms_dhoni': 2,
#  'neymar': 3,
#  'rohit_sharma': 4,
#  'Ronaldo': 5,
#  'virat_kohli': 6}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\bristi\anaconda3\lib\site-packages (1.1.1)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
